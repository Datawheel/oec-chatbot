# %%
# %load_ext dotenv
# %dotenv

from os import getenv

from table_selection.table import *

# %% [markdown]
# ### Table Manager Class

# %%
TABLES_PATH = getenv('TABLES_PATH')
manager = TableManager(TABLES_PATH)

# %%
manager.tables
# Out:
# [<table_selection.table.Table at 0x10d52c790>,
#  <table_selection.table.Table at 0x10d52c890>,
#  <table_selection.table.Table at 0x10d52c990>,
#  <table_selection.table.Table at 0x10d52ca90>,
#  <table_selection.table.Table at 0x10d52cb90>,
#  <table_selection.table.Table at 0x10d52ccd0>,
#  <table_selection.table.Table at 0x10d52cdd0>,
#  <table_selection.table.Table at 0x10d52ced0>,
#  <table_selection.table.Table at 0x10d52cfd0>,
#  <table_selection.table.Table at 0x10d52cc90>,
#  <table_selection.table.Table at 0x10d52d150>,
#  <table_selection.table.Table at 0x10d52d250>,
#  <table_selection.table.Table at 0x10d52d350>,
#  <table_selection.table.Table at 0x10d52d450>,
#  <table_selection.table.Table at 0x10d52d550>,
#  <table_selection.table.Table at 0x10d52d650>,
#  <table_selection.table.Table at 0x10d52d750>,
#  <table_selection.table.Table at 0x10d52d810>,
#  <table_selection.table.Table at 0x10d52d8d0>,
#  <table_selection.table.Table at 0x10d52d990>,
#  <table_selection.table.Table at 0x10d52da50>,
#  <table_selection.table.Table at 0x10d52db10>,
#  <table_selection.table.Table at 0x10d52dbd0>,
#  <table_selection.table.Table at 0x10d52dc90>,
#  <table_selection.table.Table at 0x10d52dd50>,
#  <table_selection.table.Table at 0x10d52de10>,
#  <table_selection.table.Table at 0x10d52ded0>,
#  <table_selection.table.Table at 0x10d52df90>,
#  <table_selection.table.Table at 0x10d52e050>,
#  <table_selection.table.Table at 0x10d52e110>,
#  <table_selection.table.Table at 0x10d52e210>,
#  <table_selection.table.Table at 0x10d52e310>,
#  <table_selection.table.Table at 0x10d52e410>,
#  <table_selection.table.Table at 0x10d52e4d0>,
#  <table_selection.table.Table at 0x10d52e590>,
#  <table_selection.table.Table at 0x10d52e650>,
#  <table_selection.table.Table at 0x10d52e710>,
#  <table_selection.table.Table at 0x10d52e7d0>,
#  <table_selection.table.Table at 0x10d52e890>,
#  <table_selection.table.Table at 0x10d52e950>,
#  <table_selection.table.Table at 0x10d52ea10>,
#  <table_selection.table.Table at 0x10d52ead0>,
#  <table_selection.table.Table at 0x10d52ebd0>,
#  <table_selection.table.Table at 0x10d52ecd0>,
#  <table_selection.table.Table at 0x10d52ed90>,
#  <table_selection.table.Table at 0x10d52ee50>,
#  <table_selection.table.Table at 0x10d52ef10>,
#  <table_selection.table.Table at 0x10d52efd0>,
#  <table_selection.table.Table at 0x10d52f090>,
#  <table_selection.table.Table at 0x10d52f150>,
#  <table_selection.table.Table at 0x10d52f210>,
#  <table_selection.table.Table at 0x10d52f2d0>,
#  <table_selection.table.Table at 0x10d52f390>,
#  <table_selection.table.Table at 0x10d52f450>,
#  <table_selection.table.Table at 0x10d52f510>,
#  <table_selection.table.Table at 0x10d52f5d0>,
#  <table_selection.table.Table at 0x10d52f690>,
#  <table_selection.table.Table at 0x10d52f750>,
#  <table_selection.table.Table at 0x10d52f810>,
#  <table_selection.table.Table at 0x10d52f8d0>,
#  <table_selection.table.Table at 0x10d52f990>,
#  <table_selection.table.Table at 0x10d52fa50>]

# %%
tables = manager.get_table_schemas(['trade_i_baci_a_92'])
print(tables)
# Out:
# Table Name: trade_i_baci_a_92
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()

# %%
tables = manager.get_table_schemas()
print(tables)
# Out:
# Table Name: trade_i_baci_a_92
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_96
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_02
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_07
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_12
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_17
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: trade_i_baci_a_22
# Description:
# Dimensions: Year (), HS Product (), Exporter (), Importer (), Unit ()
# Measures: Trade Value (), Quantity ()
#
#
# Table Name: tariffs_i_wits_a_hs_new
# Description:
# Dimensions: Year (), Agreement (), Reporter (), Partner (), HS Product ()
# Measures: Tariff ()
#
#
# Table Name: cross_hs
# Description:
# Dimensions: ID (), Classification (), Level (), Cube (), Source ()
# Measures: Count ()
#
#
# Table Name: multiple_cross_products
# Description:
# Dimensions: Master (), Product (), Classification (), Source (), Type (), HS92 (), HS96 (), HS02 (), HS07 (), HS12 (), HS17 (), HS22 (), SITC2 (), EGW (), CPF (), Other ()
# Measures: Count ()
#
#
# Table Name: trade_s_rus_m_hs
# Description:
# Dimensions: Original Product (), Subnat Geography (), Partner (), Trade Flow (), Time (), Product (), Unit ()
# Measures: Trade Value (), Weight (), Quantity ()
#
#
# Table Name: trade_s_esp_m_hs
# Description:
# Dimensions: Subnat Geography (), Partner (), Trade Flow (), Time (), Product (), Unit ()
# Measures: Trade Value (), Weight (), Quantity (), Unit Value ()
#
#
# Table Name: trade_unit_value_96
# Description:
# Dimensions: Year (), HS Product (), Reporter (), Partner (), Trade Flow ()
# Measures: Unit Value ()
#
#
# Table Name: trade_unit_value_02
# Description:
# Dimensions: Year (), HS Product (), Reporter (), Partner (), Trade Flow ()
# Measures: Unit Value ()
#
#
# Table Name: trade_unit_value_07
# Description:
# Dimensions: Year (), HS Product (), Reporter (), Partner (), Trade Flow ()
# Measures: Unit Value ()
#
#
# Table Name: trade_unit_value_12
# Description:
# Dimensions: Year (), HS Product (), Reporter (), Partner (), Trade Flow ()
# Measures: Unit Value ()
#
#
# Table Name: complexity_eci_multidimensional
# Description:
# Dimensions: Year (), ECI Research Rank (), ECI Technology Rank (), Country ()
# Measures: ECI Research (), ECI Technology ()
#
#
# Table Name: complexity_pci_a_hs02_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs07_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs12_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs92_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs96_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs22_hs6
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs02_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs07_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs12_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs92_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs96_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: complexity_pci_a_hs22_hs4
# Description:
# Dimensions: Year (), PCI Rank (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: services_i_comtrade_a_eb02
# Description:
# Dimensions: Year (), Trade Flow (), Reporter (), Partner (), Service ()
# Measures: Service Value ()
#
#
# Table Name: trade_i_comtrade_a_sitc2
# Description:
# Dimensions: Year (), Reporter (), Partner (), Trade Flow (), Product (), Unit ()
# Measures: Trade Value (), Weight (), Quantity ()
#
#
# Table Name: trade_i_comtrade_a_hs92
# Description:
# Dimensions: Year (), HS Product (), Trade Flow (), Reporter (), Partner (), Unit ()
# Measures: Trade Value (), Quantity (), Net Weight ()
#
#
# Table Name: legacy_complexity_pci_a_hs92_hs6
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs96_hs6
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs02_hs6
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs07_hs6
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs92_hs4
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs96_hs4
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs02_hs4
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_pci_a_hs07_hs4
# Description:
# Dimensions: Year (), HS Product ()
# Measures: PCI ()
#
#
# Table Name: legacy_complexity_eci_a
# Description:
# Dimensions: Year (), Country ()
# Measures: ECI ()
#
#
# Table Name: trade_i_oec_a_sitc2
# Description:
# Dimensions: Year (), Exporter (), Importer (), Product (), Unit ()
# Measures: Trade Value (), Weight (), Quantity ()
#
#
# Table Name: trade_i_comtrade_m_hs
# Description:
# Dimensions: Time (), Trade Flow (), Reporter (), Partner (), HS Product ()
# Measures: Trade Value (), Net Weight ()
#
#
# Table Name: complexity_eci_a_hs02_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs07_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs12_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs92_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs96_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs22_hs6
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs02_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs07_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs12_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs92_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs96_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: complexity_eci_a_hs22_hs4
# Description:
# Dimensions: Year (), ECI Rank (), Country ()
# Measures: ECI ()
#
#
# Table Name: indicators_i_wdi_a
# Description:
# Dimensions: Year (), Country (), Indicator ()
# Measures: Measure ()
#
#
# Table Name: trade_bloc
# Description:
# Dimensions: Trade Bloc ()
# Measures: Number of Countries ()
#
#
# Table Name: trade_wld
# Description:
# Dimensions: ID (), Name ()
# Measures: Value ()
#
#
# Table Name: hs_master_cube
# Description:
# Dimensions: Product ()
# Measures: Count ()
#
#
# Table Name: Companies
# Description:
# Dimensions: Company Level ()
# Measures: Companies ()
#
#
# Table Name: gini_inequality_income
# Description:
# Dimensions: Year (), Country ()
# Measures: Gini Coefficient ()
#
#
# Table Name: currency_rates
# Description:
# Dimensions: Currency (), Time ()
# Measures: Rate ()

# %%
manager.list_tables()
# Out:
# ['trade_i_baci_a_92',
#  'trade_i_baci_a_96',
#  'trade_i_baci_a_02',
#  'trade_i_baci_a_07',
#  'trade_i_baci_a_12',
#  'trade_i_baci_a_17',
#  'trade_i_baci_a_22',
#  'tariffs_i_wits_a_hs_new',
#  'cross_hs',
#  'multiple_cross_products',
#  'trade_s_rus_m_hs',
#  'trade_s_esp_m_hs',
#  'trade_unit_value_96',
#  'trade_unit_value_02',
#  'trade_unit_value_07',
#  'trade_unit_value_12',
#  'complexity_eci_multidimensional',
#  'complexity_pci_a_hs02_hs6',
#  'complexity_pci_a_hs07_hs6',
#  'complexity_pci_a_hs12_hs6',
#  'complexity_pci_a_hs92_hs6',
#  'complexity_pci_a_hs96_hs6',
#  'complexity_pci_a_hs22_hs6',
#  'complexity_pci_a_hs02_hs4',
#  'complexity_pci_a_hs07_hs4',
#  'complexity_pci_a_hs12_hs4',
#  'complexity_pci_a_hs92_hs4',
#  'complexity_pci_a_hs96_hs4',
#  'complexity_pci_a_hs22_hs4',
#  'services_i_comtrade_a_eb02',
#  'trade_i_comtrade_a_sitc2',
#  'trade_i_comtrade_a_hs92',
#  'legacy_complexity_pci_a_hs92_hs6',
#  'legacy_complexity_pci_a_hs96_hs6',
#  'legacy_complexity_pci_a_hs02_hs6',
#  'legacy_complexity_pci_a_hs07_hs6',
#  'legacy_complexity_pci_a_hs92_hs4',
#  'legacy_complexity_pci_a_hs96_hs4',
#  'legacy_complexity_pci_a_hs02_hs4',
#  'legacy_complexity_pci_a_hs07_hs4',
#  'legacy_complexity_eci_a',
#  'trade_i_oec_a_sitc2',
#  'trade_i_comtrade_m_hs',
#  'complexity_eci_a_hs02_hs6',
#  'complexity_eci_a_hs07_hs6',
#  'complexity_eci_a_hs12_hs6',
#  'complexity_eci_a_hs92_hs6',
#  'complexity_eci_a_hs96_hs6',
#  'complexity_eci_a_hs22_hs6',
#  'complexity_eci_a_hs02_hs4',
#  'complexity_eci_a_hs07_hs4',
#  'complexity_eci_a_hs12_hs4',
#  'complexity_eci_a_hs92_hs4',
#  'complexity_eci_a_hs96_hs4',
#  'complexity_eci_a_hs22_hs4',
#  'indicators_i_wdi_a',
#  'trade_bloc',
#  'trade_wld',
#  'hs_master_cube',
#  'Companies',
#  'gini_inequality_income',
#  'currency_rates']

# %%
table = manager.get_table('dot_faf')
print(table)
# Out:
# Table Name: dot_faf
# Description: Table 'dot_faf' has freight movement among states and major metropolitan areas by all modes of transportation. Shows which goods are shipped from one region of the US to another region, according to type of commodity, mode of shipment, value, and weight.
# Measures: Millions Of Dollars: value in millions of dollars of a certain shipment., Thousands Of Tons: weight in thousands of tons of a certain shipment.
# Variables: Year: year, SCTG2: products based on SCTG classification (first level)., Transportation Mode: mode of transportation or shipment., Origin State: Origin state, Origin Region: Origin region, Destination State: Destination state, Destination Region: Destination region

# %% [markdown]
# ### Table Class

# %%
table.name
# Out:
# 'dot_faf'

# %%
table.api
# Out:
# 'Tesseract'

# %%
columns = table.columns_description()
print(columns, "\n")
# Out:
# Table Name: dot_faf
# Variables:
# Year (year) [Parent dimension: Year];
# SCTG2 (products based on SCTG classification (first level).) [Parent dimension: SCTG2];
# Transportation Mode (mode of transportation or shipment.) [Parent dimension: Transportation Mode];
# Origin State (Origin state) [Parent dimension: Origin];
# Origin Region (Origin region) [Parent dimension: Origin];
# Destination State (Destination state) [Parent dimension: Destination];
# Destination Region (Destination region) [Parent dimension: Destination];
# Measures:
# Millions Of Dollars (value in millions of dollars of a certain shipment.);
# Thousands Of Tons (weight in thousands of tons of a certain shipment.);

# %%
table.get_variables_description()
# Out:
# ['Year: year',
#  'SCTG2: products based on SCTG classification (first level).',
#  'Transportation Mode: mode of transportation or shipment.',
#  'Origin State: Origin state',
#  'Origin Region: Origin region',
#  'Destination State: Destination state',
#  'Destination Region: Destination region']

# %%
table.variables
# Out:
# [{'name': 'Year',
#   'description': 'year',
#   'parent dimension': 'Year',
#   'hierarchies': ['Year']},
#  {'name': 'SCTG2',
#   'description': 'products based on SCTG classification (first level).',
#   'parent dimension': 'SCTG2',
#   'hierarchies': ['SCTG2']},
#  {'name': 'Transportation Mode',
#   'description': 'mode of transportation or shipment.',
#   'parent dimension': 'Transportation Mode',
#   'hierarchies': ['Transportation Mode']},
#  {'name': 'Origin State',
#   'description': 'Origin state',
#   'parent dimension': 'Origin',
#   'hierarchies': ['Origin State', 'Origin Region']},
#  {'name': 'Origin Region',
#   'description': 'Origin region',
#   'parent dimension': 'Origin',
#   'hierarchies': ['Origin State', 'Origin Region']},
#  {'name': 'Destination State',
#   'description': 'Destination state',
#   'parent dimension': 'Destination',
#   'hierarchies': ['Destination State', 'Destination Region']},
#  {'name': 'Destination Region',
#   'description': 'Destination region',
#   'parent dimension': 'Destination',
#   'hierarchies': ['Destination State', 'Destination Region']}]

# %%
table.measures
# Out:
# [{'name': 'Millions Of Dollars',
#   'description': 'value in millions of dollars of a certain shipment.'},
#  {'name': 'Thousands Of Tons',
#   'description': 'weight in thousands of tons of a certain shipment.'}]

# %%
print(table)
# Out:
# Table Name: dot_faf
# Description: Table 'dot_faf' has freight movement among states and major metropolitan areas by all modes of transportation. Shows which goods are shipped from one region of the US to another region, according to type of commodity, mode of shipment, value, and weight.
# Measures: Millions Of Dollars: value in millions of dollars of a certain shipment., Thousands Of Tons: weight in thousands of tons of a certain shipment.
# Variables: Year: year, SCTG2: products based on SCTG classification (first level)., Transportation Mode: mode of transportation or shipment., Origin State: Origin state, Origin Region: Origin region, Destination State: Destination state, Destination Region: Destination region
